# %% [markdown]
# <a href="https://colab.research.google.com/github/AdamayB/AI-Copilot/blob/main/CodeGenerator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/huggingface/transformers.git -q
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 3.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 13.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 20.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 19.6 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

# %%
tokenizer = AutoTokenizer.from_pretrained("Salesforce/codegen-350M-mono")
model = AutoModelForCausalLM.from_pretrained("Salesforce/codegen-350M-mono")
# Out:
# ...
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# ...

# %%
text = "an integer as user input and convert it into its binary equivalent "

# %%
input_ids = tokenizer(text, return_tensors="pt").to(device).input_ids

# %%
model = model.to(device)

# %%
generated_ids = model.generate(input_ids, max_length=1024)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
print(tokenizer.decode(generated_ids[0], skip_special_tokens=True))
# Out:
# an integer as user input and convert it into its binary equivalent
#     # and store it in a variable called binary.
#     binary = int(input("Enter a binary number: "))
#     # print(binary)
#     # print(bin(binary))
#     # print(bin(binary)[2:])
#     # print(bin(binary)[:-2])
#     # print(bin(binary)[:-2])
#     # print(bin(binary)[:-2])
#     # print(bin(binary)[:-2])
#     # print(bin(binary)[:-2])
#     # print(bin(binary)[:-2])
#     # print(bin(binary)[:-2])
#     # print(bin(binary)[:-2])
#     # print(bin(binary)[:-2])
#     # print(bin(binary)[:-2])
#     # print(bin(binary)[:-2])
#     # print(bin(binary)[:-2])
#     # print(bin(binary)[:-2])
#     # print(bin(binary)[:-2])
#     # print(bin(binary)[:-2])
#     # print(bin(binary)[:-2])
#     # print(bin(binary)[:-2])
#     # print(bin(binary)[:-2])
#     # print(bin(binary)[:-2])
#     # print(bin(binary)[:-2])
#     # print(bin(binary)[:-2])
#     # print(bin(binary)[:-2])
#     # print(bin(binary)[:-2])
# ...

# %%
binary = int(input("Enter a binary number: "))
print(binary)
print(bin(binary))
# Out:
# Enter a binary number: 7
# 7
# 0b111
